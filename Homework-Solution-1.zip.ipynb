# %%
# for basic operation
import numpy as pd
import pandas as pd

# for Data Visualizations
import matplotlib.pyplot as plt
import seaborn as sns

# setting the Chart
plt.rcParams['figure.figsize'] = (16, 5)
plt.style.use('fivethirtyeight')

# %%
# lets read the dataset
data = pd.read_csv(r"C:\Users\Piyush GAJ\Downloads\Mall_Customers.csv")
print(data.shape)
print(data.columns)
# Out:
# (10, 5)
# Index(['CustomerID', 'Gender', 'Age', 'Annual Income (k$)',
#        'Spending Score (1-100)'],
#       dtype='object')

# %% [markdown]
# Divide Age into Discrete Categories

# %%
print("Minimum Age :", data['Age'].min())
print("Maximum Age :", data['Age'].max())
# Out:
# Minimum Age : 19
# Maximum Age : 64

# %%
# lets create a function to divide age into discrete categories
def age(x):
    if x <= 35:
        return "Younng"
    else:
        return "Old"

data['Age'] = data['Age'].apply(age)
data['Age'].value_counts()
# Out:
# Age
# Younng    9
# Old       1
# Name: count, dtype: int64

# %% [markdown]
# Understanding the Impact of Spending score
# on Different Age Groups

# %%
# lets use the groupby function to understand that
data[['Age', 'Spending Score (1-100)']].groupby(['Age']).agg(['min','mean','max']).style.background_gradient(cmap = 'copper')
# Out:
# <style type="text/css">
# #T_be5b2_row0_col0, #T_be5b2_row0_col1, #T_be5b2_row0_col2 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_be5b2_row1_col0, #T_be5b2_row1_col1, #T_be5b2_row1_col2 {
#   background-color: #ffc77f;
#   color: #000000;
# }
# </style>
# <table id="T_be5b2">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_be5b2_level0_col0" class="col_heading level0 col0" colspan="3">Spending Score (1-100)</th>
#     </tr>
#     <tr>
#       <th class="blank level1" >&nbsp;</th>
#       <th id="T_be5b2_level1_col0" class="col_heading level1 col0" >min</th>
#       <th id="T_be5b2_level1_col1" class="col_heading level1 col1" >mean</th>
#       <th id="T_be5b2_level1_col2" class="col_heading level1 col2" >max</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Age</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_be5b2_level0_row0" class="row_heading level0 row0" >Old</th>
#       <td id="T_be5b2_row0_col0" class="data row0 col0" >3</td>
#       <td id="T_be5b2_row0_col1" class="data row0 col1" >3.000000</td>
#       <td id="T_be5b2_row0_col2" class="data row0 col2" >3</td>
#     </tr>
#     <tr>
#       <th id="T_be5b2_level0_row1" class="row_heading level0 row1" >Younng</th>
#       <td id="T_be5b2_row1_col0" class="data row1 col0" >6</td>
#       <td id="T_be5b2_row1_col1" class="data row1 col1" >54.555556</td>
#       <td id="T_be5b2_row1_col2" class="data row1 col2" >94</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Find out the Top 10 Target Customers

# %%
# To get the Target Customers we will use the Spending score and the Annual Income

data[['Annual Income (k$)','Spending Score (1-100)']].head()
# Out:
#    Annual Income (k$)  Spending Score (1-100)
# 0                  15                      39
# 1                  15                      81
# 2                  16                       6
# 3                  16                      77
# 4                  17                      40

# %%
# let's filter the Top Customers
data[['CustomerID','Annual Income (k$)','Spending Score (1-100)']][(data['Annual Income (k$)'] > 75)
        & (data['Spending Score (1-100)'] > 75)].sort_values(by = 'Spending Score (1-100)', ascending = False).head(10)
# Out:
# Empty DataFrame
# Columns: [CustomerID, Annual Income (k$), Spending Score (1-100)]
# Index: []
